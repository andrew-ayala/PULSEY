# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

fig,ax = plt.subplots()
ax.scatter(np.arange(100),np.sin(np.arange(100)))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
